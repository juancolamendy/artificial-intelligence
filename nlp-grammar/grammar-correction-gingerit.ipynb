# %% [markdown]
# # Install dep

# %%
# !pip install gingerit

# %% [markdown]
# # Import dep

# %%
from gingerit.gingerit import GingerIt

# %% [markdown]
# # Logic

# %%
text = 'The smelt of the fliowers bring back memories.'

parser = GingerIt()
result = parser.parse(text)

print(result)
print(result['result'])
# Out:
# {'text': 'The smelt of the fliowers bring back memories.', 'result': 'The smell of the flowers brings back memories.', 'corrections': [{'start': 26, 'text': 'bring', 'correct': 'brings', 'definition': None}, {'start': 17, 'text': 'fliowers', 'correct': 'flowers', 'definition': 'a plant cultivated for its blooms or blossoms'}, {'start': 4, 'text': 'smelt', 'correct': 'smell', 'definition': None}]}
# The smell of the flowers brings back memories.
