# %%
# !pip install transformers

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")

# %%
# !ls ~/.cache/huggingface/transformers

# %%
sequence_to_classify = "one day I will see the world"
candidate_labels = ['travel', 'cooking', 'dancing']
output = classifier(sequence_to_classify, candidate_labels)
print(output)
# Out:
# {'sequence': 'one day I will see the world', 'labels': ['travel', 'dancing', 'cooking'], 'scores': [0.9938651323318481, 0.003273765789344907, 0.002861053217202425]}

# %% [markdown]
# [Source](https://huggingface.co/facebook/bart-large-mnli)

# %%
# !free -g
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:             12           3           4           0           4           8
# Swap:             0           0           0
