# %% [markdown]
# # Install dep

# %%
# !pip install --quiet transformers
# Out:
#      |████████████████████████████████| 2.5MB 6.2MB/s
#      |████████████████████████████████| 901kB 35.4MB/s
#      |████████████████████████████████| 3.3MB 21.4MB/s

# %% [markdown]
# # Import dep

# %%
from transformers import pipeline

# %% [markdown]
# # Prepare the pipeline

# %%
qa = pipeline("question-answering")

# %% [markdown]
# # Business logic

# %%
# Open and read the article
question = "What is the capital of the Netherlands?"
context = r"The four largest cities in the Netherlands are Amsterdam, Rotterdam, The Hague and Utrecht.[17] Amsterdam is the country's most populous city and nominal capital,[18] while The Hague holds the seat of the States General, Cabinet and Supreme Court.[19] The Port of Rotterdam is the busiest seaport in Europe, and the busiest in any country outside East Asia and Southeast Asia, behind only China and Singapore."

# Generating an answer to the question in context
answer = qa(question=question, context=context)

# Print the answer
print(f"Question: {question}")
print(f"Answer: '{answer['answer']}' with score {answer['score']}")
# Out:
# Question: What is the capital of the Netherlands?
# Answer: 'Amsterdam' with score 0.3774995803833008

# %%
question="What is Roman empire known for?"
context = r"The Roman Empire, at its height (c. 117 CE), was the most extensive political and social structure in western civilization. By 285 CE the empire had grown too vast to be ruled from the central government at Rome and so was divided by Emperor Diocletian (r. 284-305 CE) into a Western and an Eastern Empire. The Roman Empire began when Augustus Caesar (r. 27 BCE-14 CE) became the first emperor of Rome and ended, in the west, when the last Roman emperor, Romulus Augustulus (r. 475-476 CE), was deposed by the Germanic King Odoacer (r. 476-493 CE). In the east, it continued as the Byzantine Empire until the death of Constantine XI (r. 1449-1453 CE) and the fall of Constantinople to the Ottoman Turks in 1453 CE. The influence of the Roman Empire on western civilization was profound in its lasting contributions to virtually every aspect of western culture."

# Generating an answer to the question in context
answer = qa(question=question, context=context)

# Print the answer
print(f"Question: {question}")
print(f"Answer: '{answer['answer']}' with score {answer['score']}")
# Out:
# Question: What is Roman empire known for?
# Answer: 'the most extensive political and social structure in western civilization' with score 0.21964982151985168
