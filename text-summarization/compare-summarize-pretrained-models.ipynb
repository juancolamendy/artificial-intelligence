# %% [markdown]
# # Install dependencies

# %%
# !pip install --quiet transformers==2.9.0

# %% [markdown]
# # Init

# %%
paragraph = """
Want to know a smart way to redirect high-quality traffic. So, when someone clicks link from a shortener, it will be redirected to one of the pages in your defined groups.
A link rotator software or traffic rotator is a particular type of shortened link that routes your visitors to different destinations. This is sometimes also called an URL rotator or traffic rotator.
*The best part?*
Keep reading because I will explain in this guide how to rotate urls, so you can improve your marketing campaigns in 2021.
A link rotators are a type of shorteners that allows to rotate urls and redirects your visitors to different destinations. A link rotator allows you to redirect a visitor to different pages that you have added to the rotator when they click on your base shortened link.
It can be used for A/B testing, sharing traffic with different partners, or showing visitors different messages when they click on the same link more than once. This is particularly helpful when you're tracking conversions. For example, the content creator could send 50% of the traffic to destination A and 50% of the traffic to destination B. The content creator would then be able to compare the traffic sent to destination A vs. the traffic sent to destination B to determine which is most effective.
In summary, a content creator might use a link rotator to increase the chance that a user will end up on a site that they want them to visit by splitting the traffic to multiple destinations following different rotation rules.
Link rotators are usually a feature of url shorteners specially built for marketers. When you create a link rotator link, you add multiple destinations, and the amount of traffic you want to send to each. When a visitor visits the link, the link rotator's server generates a random number, and allocates a destination, in the proportion you defined.
A link rotator is a feature of URL shorteners that allows you to add multiple destinations, and the proportion of traffic you want to send to each. When someone visits the link, the link rotator's server generates a random number, and allocates a destination. The link rotator then chooses one of the destinations you've entered. The link rotator then redirects the user to the chosen destination, so they can access the content. This is an interesting concept that's now used by many large websites, such as YouTube, Facebook, YouTube, Wikipedia, YouTube, Google Drive, and many more.
Sometimes, marketers will want to make a link rotator sticky, so that when a user clicks on a link twice, they always go to the same offer or landing page. This ensures that the visitor does not get confused and changed landing pages after clicking on a link. When a user clicks on a link twice, they always go to the same offer or landing page, you will want to make sure that the visitor doesn't get confused and change landing pages after clicking on a link.
Sticky link rotators work by saving a cookie on the user's browser that identifies them. When a click comes through again with that cookie attached, the link rotation service knows which destination to send them to.
Link rotators are a tool to drive traffic to different landing pages to test which page has a higher conversion rate. It is a very common practice for SEOs to use link rotators as a tool to rank higher within search engines. The main reason for this is that link rotators allow you to redirect traffic to different pages and test the impact of those pages on your traffic.
For instance, you could redirect all of your visitors to a landing page where you ask them to fill in a short survey. This is an effective way to increase conversions by having the visitors answer the survey for you. Moreover, link rotators are a great way to increase conversions by offering different types of content on your website. You can offer a list of links that redirects to different pages of your website. This way you can offer a wide range of content and increase conversions by offering different types of content.
Content creators can understand that people often use link rotators to see which of two landing pages (e.g. A or B) has a higher conversion rate. Some people also use link rotators to test different prices and one-time sale vs. subscription offers.
However link rotators are not allowed in some affiliate programs. The best way to create affiliate links is to use choice pages (interstitial landing pages) to offer visitors different storefronts for the same product. If a visitor clicks a link off a choice page to a particular product, they will go directly to the storefront of the product along with a shortener.
As well, content creators can understand that they would want conversion tracking if they are showing different offers to different people. Conversion tracking is the process of recording not just which URL a visitor went to, but what they purchased.
"""

# %% [markdown]
# # T5

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# %%
model = T5ForConditionalGeneration.from_pretrained('t5-base')
tokenizer = T5Tokenizer.from_pretrained('t5-base')
print('tokenizer:', tokenizer)

# %%
text = paragraph
preprocessed_text = "summarize: " + text
tokens_input = tokenizer.encode(preprocessed_text, return_tensors="pt", max_length=512, truncation=True)
summary_ids = model.generate(tokens_input, min_length=60, max_length=180, length_penalty=4.0)
summary = tokenizer.decode(summary_ids[0])
print(summary)
# Out:
# a link rotator software or traffic rotator is a particular type of shortened link. it allows you to rotate urls and redirect visitors to different destinations. this is sometimes also called an URL rotator or traffic rotator. it can be used for A/B testing, sharing traffic with different partners.

# %% [markdown]
# # Bart

# %%
from transformers import pipeline

# %%
summarizer = pipeline('summarization', model='facebook/bart-large-cnn', tokenizer='facebook/bart-large-cnn')

# %%
text = paragraph
result = summarizer(text, min_length = round(0.1 * len(text.split(' '))), max_length = round(0.2 * len(text.split(' '))), do_sample=False)
print(result)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# ...
