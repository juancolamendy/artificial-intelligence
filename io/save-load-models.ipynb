# %%
# !pip install --quiet transformers
# Out:
#      |████████████████████████████████| 2.1MB 18.0MB/s
#      |████████████████████████████████| 870kB 37.8MB/s
#      |████████████████████████████████| 3.3MB 33.5MB/s
# ...

# %%
from transformers import BertModel

model = BertModel.from_pretrained("bert-base-cased")

# %%
# !ls -alh ~/.cache/huggingface/transformers

# %% [markdown]
# ## Notes
# You also have to save the tokenizer into the same directory.
# ```tokenizer.save_pretrained("./roberta-large-355M")```

# %%
model.save_pretrained("./saved_bert")

# %%
# !ls -alh saved_bert/
# Out:
# total 414M
# drwxr-xr-x 2 root root 4.0K Apr 15 11:19 .
# drwxr-xr-x 1 root root 4.0K Apr 15 11:19 ..
# -rw-r--r-- 1 root root  597 Apr 15 11:19 config.json
# -rw-r--r-- 1 root root 414M Apr 15 11:19 pytorch_model.bin

# %%
loaded_model = BertModel.from_pretrained('./saved_bert')
